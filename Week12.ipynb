# %% [markdown]
# <a href="https://colab.research.google.com/github/ikypakey/PCVK/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# akses drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/img/facedetection/haarcascade_frontalface_alt.xml')
jokowi = cv.imread('/content/drive/MyDrive/img/facedetection/jokowi.jpg',0)
roi_wajah = cascade_wajah.detectMultiScale(jokowi) 
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
 plt.figure(figsize = (10,10))
 plt.imshow(jokowi, cmap='gray')

# %% [markdown]
# ## No 2. Face Detection Other Image

# %%
# (face det)
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive//img/facedetection/haarcascade_frontalface_alt.xml')

# Jokowi
jokowi = cv.imread('/content/drive/MyDrive/img/facedetection/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/img/facedetection/jokowi.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(jokowi1) 

roi_wajah = cascade_wajah.detectMultiScale(jokowi) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Kartini
kartini = cv.imread('/content/drive/MyDrive/img/facedetection/kartini.jpg')
kartini1 = cv.imread('/content/drive/MyDrive/img/facedetection/kartini.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(kartini1) 

roi_wajah = cascade_wajah.detectMultiScale(kartini) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(kartini,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Kucing
kucing = cv.imread('/content/drive/MyDrive/img/facedetection/mycat.jpg')
kucing2 = cv.imread('/content/drive/MyDrive/img/facedetection/mycat.jpg')

kucing_ori = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)
kucing_kw = cv.cvtColor(kucing2, cv.COLOR_BGR2GRAY)


roi_wajah = cascade_wajah.detectMultiScale(kucing2)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(kucing2,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing_ori, cmap='gray')
plt.subplot(122),plt.imshow(kucing_kw, cmap='gray')
plt.show()

# %%
#Mask
mask = cv.imread('/content/drive/MyDrive/img/facedetection/mask.png',0)
mask1 = cv.imread('/content/drive/MyDrive/img/facedetection/mask.png',0)

roi_wajah = cascade_wajah.detectMultiScale(mask1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(mask1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask, cmap='gray')
plt.subplot(122),plt.imshow(mask1, cmap='gray')
plt.show()

# %%
#Jordan
jordan = cv.imread('/content/drive/MyDrive/img/facedetection/mjordan.jpg',0)
jordan1 = cv.imread('/content/drive/MyDrive/img/facedetection/mjordan.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(jordan1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jordan1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(jordan, cmap='gray')
plt.subplot(122),plt.imshow(jordan1, cmap='gray')
plt.show()

# %%
#Solvayconf
kelompok = cv.imread('/content/drive/MyDrive/img/facedetection/solvayconf.jpg',0)
kelompok1 = cv.imread('/content/drive/MyDrive/img/facedetection/solvayconf.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(kelompok1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(kelompok1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kelompok, cmap='gray')
plt.subplot(122),plt.imshow(kelompok1, cmap='gray')
plt.show()

# %% [markdown]
# # 3. Deteksi Wajah Kucing

# %%
cascade_wajah = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalcatface.xml")

ucing = cv.imread('/content/drive/MyDrive/img/facedetection/mycat.jpg',0)
ucingku = cv.imread('/content/drive/MyDrive/img/facedetection/mycat.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(ucingku)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(ucingku,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(ucing, cmap='gray')
plt.subplot(122),plt.imshow(ucingku, cmap='gray')
plt.show()

# %% [markdown]
# # 4. Eye Detection

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive//img/facedetection/haarcascade_eye.xml')

# JOKOWI
jokowi = cv.imread('/content/drive/MyDrive/img/facedetection/jokowi.jpg')
jokowi_pro = cv.imread('/content/drive/MyDrive/img/facedetection/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)
jokowi_ori_gray = cv.cvtColor(jokowi_pro, cv.COLOR_BGR2GRAY)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_ori_gray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %% [markdown]
# # 5. Face Tracking

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img


def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))
  
  return bbox_to_bytes

# %%
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality){
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  faces = face_cascade.detectMultiScale(gray)
  for(x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255, 0, 0),2)

  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))

  display(Image(filename))
except Exception as err:
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %% [markdown]
# # 6. Detect Mjordan

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/img/facedetection/haarcascade_frontalface_alt.xml')

mjordan_img = cv2.imread('/content/drive/MyDrive/img/facedetection/mjordan.jpg')
smile = cv2.imread('/content/drive/MyDrive/img/facedetection/smile.png', cv2.IMREAD_UNCHANGED)

gray = cv2.cvtColor(jordan_img, cv2.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    smile_resized = cv2.resize(smile, (w, h))
    mjordan_img[y:y+h, x:x+w] = cv2.addWeighted(mjordan_img[y:y+h, x:x+w], 1, smile_resized[:, :, 0:3], 1, 0)

plt.figure(figsize=(15, 5))
plt.subplot(111), plt.imshow(cv2.cvtColor(mjordan_img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 7. Bounding Box

# %%
bounding_box = cv2.imread('/content/drive/MyDrive/img/facedetection/people.jpg')

gray_image = cv2.cvtColor(bounding_box, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/img/facedetection/haarcascade_frontalface_alt.xml')
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    cv2.rectangle(bounding_box, (x, y), (x+w, y+h), (0, 0, 0), 2)

    roi_gray = gray_image[y:y+h, x:x+w]
    eye_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/img/facedetection/haarcascade_eye.xml')
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)

    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 2)

        if ex + ew/2 > w/2:
            cv2.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (255, 255, 255), 2)

plt.figure(figsize=(15, 5))
plt.subplot(111), plt.imshow(cv2.cvtColor(bounding_box, cv2.COLOR_BGR2RGB))
plt.show()
